# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the file
file_path = "C:/Users/abomi/Desktop/TFM OK/TFM-main/datas/Brazil_Energy balance matrix.xlsx"

#File excel with multi-sheet_names is read as an Dictionary
Dict = pd.read_excel(file_path, sheet_name=None, skiprows=range(4), skipfooter=3)

for k in Dict.keys():       
    # Round the values of each column in dataframe with 2 decimals
    Dict[k]=Dict[k].applymap(lambda x: round(x, 2) if isinstance(x, (int, float)) else x)
    
    #Ignor the first row (unit) in each df
    Dict[k]=Dict[k][1:]
    
    #Rename of columns in df
    Dict[k].rename(columns={'Unnamed: 0': 'SECTOR','OTHER PRIMARY_x000d_\n':'OTHER PRIMARY'}, inplace=True)   
    
print(Dict.keys())

# Convert the keys of Dict to only contain the year
for k in list(Dict.keys()):
    k_new = k.split(' - ')[0]
    Dict[k_new] = Dict.pop(k)
    Dict[k_new]["Year"]=k_new
        
print('\n')
print(Dict.keys())



#Save the Clean Dictionary in Excel with multi-sheet_names
file_path="C:/Users/abomi/Desktop/TFM OK/TFM-main/datas/Brazil_Energy balance matrix_cleaned.xlsx"
with pd.ExcelWriter(file_path) as writer:
    for k, df in Dict.items():
        df.to_excel(writer, sheet_name=k)

df_2021=Dict['2021']
df_2021.tail(14)
# Out:
# dict_keys(['1970 - Brazil', '1971 - Brazil', '1972 - Brazil', '1973 - Brazil', '1974 - Brazil', '1975 - Brazil', '1976 - Brazil', '1977 - Brazil', '1978 - Brazil', '1979 - Brazil', '1980 - Brazil', '1981 - Brazil', '1982 - Brazil', '1983 - Brazil', '1984 - Brazil', '1985 - Brazil', '1986 - Brazil', '1987 - Brazil', '1988 - Brazil', '1989 - Brazil', '1990 - Brazil', '1991 - Brazil', '1992 - Brazil', '1993 - Brazil', '1994 - Brazil', '1995 - Brazil', '1996 - Brazil', '1997 - Brazil', '1998 - Brazil', '1999 - Brazil', '2000 - Brazil', '2001 - Brazil', '2002 - Brazil', '2003 - Brazil', '2004 - Brazil', '2005 - Brazil', '2006 - Brazil', '2007 - Brazil', '2008 - Brazil', '2009 - Brazil', '2010 - Brazil', '2011 - Brazil', '2012 - Brazil', '2013 - Brazil', '2014 - Brazil', '2015 - Brazil', '2016 - Brazil', '2017 - Brazil', '2018 - Brazil', '2019 - Brazil', '2020 - Brazil', '2021 - Brazil'])
#
#
# dict_keys(['1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'])
#                                 SECTOR      OIL NATURAL GAS      COAL  \
# 14                       OTHER CENTERS  -734.46         NaN       NaN
# 15                TOTAL TRANSFORMATION -93286.2   -20068.66 -12255.29
# 16                     OWN CONSUMPTION      NaN     4706.08       NaN
# 17                              LOSSES      NaN      241.54      17.9
# 18                          ADJUSTMENT    54.58      -55.21      0.49
# 19                          TRANSPORT       NaN      1903.2       NaN
# 20                          INDUSTRIAL      NaN     8417.91   3497.42
# 21                         RESIDENTIAL      NaN      454.97       NaN
# 22        COMMERCIAL, SERVICES, PUBLIC      NaN      136.77       NaN
# 23     AGRICULTURE, FISHING AND MINING      NaN      261.08    146.11
# 24             CONSTRUCTION AND OTHERS      NaN         NaN       NaN
# 25                  ENERGY CONSUMPTION      NaN    11173.92   3643.53
# 26              NON-ENERGY CONSUMPTION      NaN      215.94       NaN
# 27                   FINAL CONSUMPTION      NaN    11389.86   3643.53
#
#    HYDROENERGY GEOTHERMAL  NUCLEAR  FIREWOOD SUGARCANE AND PRODUCTS  \
# 14         NaN        NaN      NaN       NaN                    NaN
# 15   -31125.01        NaN -3835.75  -7775.51              -21164.15
# 16         NaN        NaN      NaN       NaN                12887.1
# 17         NaN        NaN      NaN       NaN                    NaN
# 18         0.0        NaN      NaN       NaN                    0.0
# 19         NaN        NaN      NaN       NaN                    NaN
# 20         NaN        NaN      NaN   7588.34                15418.5
# 21         NaN        NaN      NaN   7422.22                    NaN
# 22         NaN        NaN      NaN     81.99                    NaN
# 23         NaN        NaN      NaN    3149.9                    NaN
# 24         NaN        NaN      NaN       NaN                    NaN
# 25         NaN        NaN      NaN  18242.44                15418.5
# 26         NaN        NaN      NaN       NaN                    NaN
# 27         NaN        NaN      NaN  18242.44                15418.5
#
#    OTHER PRIMARY  ... DIESEL OIL FUEL OIL     COKE CHARCOAL    GASES  \
# 14       -5589.7  ...    5723.21      NaN      NaN      NaN      NaN
# 15     -18575.13  ...   -1933.18 -1881.81      NaN      NaN  -394.47
# 16           NaN  ...     509.02   131.89      NaN      NaN   205.16
# 17           NaN  ...        NaN      NaN     41.3    57.86      NaN
# 18         -0.05  ...     -50.87    -0.43      0.0      0.0   -22.68
# 19           NaN  ...    42980.4   776.88      NaN      NaN      NaN
# 20       8568.38  ...     785.48  1383.83  7850.75  3359.75  1326.98
# 21        716.94  ...        NaN      NaN      NaN   411.72      NaN
# 22        176.91  ...      43.85     23.4      NaN    76.99      NaN
# 23           NaN  ...    7461.33    98.82    32.48     9.11      NaN
# 24           NaN  ...        NaN      NaN      NaN      NaN      NaN
# 25       9462.23  ...   51271.06  2282.93  7883.22  3857.57  1326.98
# 26           NaN  ...        NaN      NaN      NaN      NaN   156.21
# 27       9462.23  ...   51271.06  2282.93  7883.22  3857.57  1483.19
#
#    OTHER SECONDARY NON-ENERGY TOTAL SECUNDARIES      TOTAL  Year
# 14         1580.88    -233.26           7431.85     -991.3  2021
# 15        -1906.82    -233.26          -8215.28  -26510.47  2021
# 16         3078.97        NaN           7258.66   24851.84  2021
# 17             NaN        NaN            9456.1    9715.53  2021
# 18           28.88      89.41            130.32     130.14  2021
# 19             NaN        NaN           83272.9    85176.1  2021
# 20         5931.98        NaN          38899.12   82389.66  2021
# 21             NaN        NaN          19827.62   28421.75  2021
# 22             NaN        NaN          12152.68   12548.34  2021
# 23          196.57        NaN           11864.6   15421.69  2021
# 24             NaN        NaN               NaN        NaN  2021
# 25         6128.55        NaN         166016.93  223957.54  2021
# 26             NaN    6626.69          13021.03   13236.97  2021
# 27         6128.55    6626.69         179037.96  237194.52  2021
#
# [14 rows x 25 columns]

# %%
df_2021.SECTOR
# Out:
# 1                                     PRODUCTION
# 2                                         IMPORT
# 3                                         EXPORT
# 4                                   STOCK CHANGE
# 5                                         UNUSED
# 6                                   TOTAL SUPPLY
# 7                                     REFINERIES
# 8                                  POWER PLANTS
# 9                                 SELF-PRODUCERS
# 10                                    GAS PLANTS
# 11                               CHARCOAL PLANTS
# 12       COKE PLANTS AND BLAST FURNACES_x000d_\n
# 13                                  DISTILLERIES
# 14                                 OTHER CENTERS
# 15                          TOTAL TRANSFORMATION
# 16                               OWN CONSUMPTION
# 17                                        LOSSES
# 18                                    ADJUSTMENT
# 19                                    TRANSPORT
# 20                                    INDUSTRIAL
# 21                                   RESIDENTIAL
# 22                  COMMERCIAL, SERVICES, PUBLIC
# 23               AGRICULTURE, FISHING AND MINING
# 24                       CONSTRUCTION AND OTHERS
# 25                            ENERGY CONSUMPTION
# 26                        NON-ENERGY CONSUMPTION
# 27                             FINAL CONSUMPTION
# Name: SECTOR, dtype: object

# %%
df_2021
# Out:
#                                         SECTOR        OIL NATURAL GAS  \
# 1                                   PRODUCTION  152713.43    26371.48
# 2                                       IMPORT    7359.21    14796.23
# 3                                       EXPORT   65724.07         NaN
# 4                                 STOCK CHANGE   -1007.78    -3598.93
# 5                                       UNUSED        NaN     1217.87
# 6                                 TOTAL SUPPLY   93340.78    36350.92
# 7                                   REFINERIES  -92551.74         NaN
# 8                                POWER PLANTS         NaN    -13219.0
# 9                               SELF-PRODUCERS        NaN    -4266.04
# 10                                  GAS PLANTS        NaN    -2583.62
# 11                             CHARCOAL PLANTS        NaN         NaN
# 12     COKE PLANTS AND BLAST FURNACES_x000d_\n        NaN         NaN
# 13                                DISTILLERIES        NaN         NaN
# 14                               OTHER CENTERS    -734.46         NaN
# 15                        TOTAL TRANSFORMATION   -93286.2   -20068.66
# 16                             OWN CONSUMPTION        NaN     4706.08
# 17                                      LOSSES        NaN      241.54
# 18                                  ADJUSTMENT      54.58      -55.21
# 19                                  TRANSPORT         NaN      1903.2
# 20                                  INDUSTRIAL        NaN     8417.91
# 21                                 RESIDENTIAL        NaN      454.97
# 22                COMMERCIAL, SERVICES, PUBLIC        NaN      136.77
# 23             AGRICULTURE, FISHING AND MINING        NaN      261.08
# 24                     CONSTRUCTION AND OTHERS        NaN         NaN
# 25                          ENERGY CONSUMPTION        NaN    11173.92
# 26                      NON-ENERGY CONSUMPTION        NaN      215.94
# 27                           FINAL CONSUMPTION        NaN    11389.86
#
#         COAL HYDROENERGY GEOTHERMAL  NUCLEAR  FIREWOOD SUGARCANE AND PRODUCTS  \
# 1    2633.08    31125.01        NaN  3835.75  26017.95               49469.74
# 2   13216.31         NaN        NaN      NaN       NaN                    NaN
# 3        NaN         NaN        NaN      NaN       NaN                    NaN
# 4      67.82         NaN        NaN      NaN       NaN                    NaN
# 5        NaN         NaN        NaN      NaN       NaN                    NaN
# 6   15917.21    31125.01        NaN  3835.75  26017.95               49469.74
# 7        NaN         NaN        NaN      NaN       NaN                    NaN
# 8   -4189.67   -29752.22        NaN -3835.75    -56.11                    NaN
# 9    -215.78    -1372.79        NaN      NaN   -373.38               -5782.78
# 10       NaN         NaN        NaN      NaN       NaN                    NaN
# 11       NaN         NaN        NaN      NaN  -7346.03                    NaN
# 12  -7849.84         NaN        NaN      NaN       NaN                    NaN
# 13       NaN         NaN        NaN      NaN       NaN              -15381.37
# 14       NaN         NaN        NaN      NaN       NaN                    NaN
# 15 -12255.29   -31125.01        NaN -3835.75  -7775.51              -21164.15
# 16       NaN         NaN        NaN      NaN       NaN                12887.1
# 17      17.9         NaN        NaN      NaN       NaN                    NaN
# 18      0.49         0.0        NaN      NaN       NaN                    0.0
# 19       NaN         NaN        NaN      NaN       NaN                    NaN
# 20   3497.42         NaN        NaN      NaN   7588.34                15418.5
# 21       NaN         NaN        NaN      NaN   7422.22                    NaN
# 22       NaN         NaN        NaN      NaN     81.99                    NaN
# 23    146.11         NaN        NaN      NaN    3149.9                    NaN
# 24       NaN         NaN        NaN      NaN       NaN                    NaN
# 25   3643.53         NaN        NaN      NaN  18242.44                15418.5
# 26       NaN         NaN        NaN      NaN       NaN                    NaN
# 27   3643.53         NaN        NaN      NaN  18242.44                15418.5
#
#    OTHER PRIMARY  ... DIESEL OIL  FUEL OIL     COKE CHARCOAL    GASES  \
# 1       28037.32  ...   41972.43  16109.25  6866.86  3915.43  2060.14
# 2            NaN  ...   12211.92    581.74  1150.16      NaN      NaN
# 3            NaN  ...      499.3  11963.08      NaN      NaN      NaN
# 4            NaN  ...     -22.66   -431.71    -92.5      NaN      NaN
# 5            NaN  ...        NaN       NaN      NaN      NaN      NaN
# 6       28037.32  ...   53662.39    4296.2  7924.52  3915.43  2060.14
# 7            NaN  ...   36249.21  16109.25      NaN      NaN      NaN
# 8       -7138.42  ...   -1371.21  -1656.49      NaN      NaN      NaN
# 9       -5688.41  ...    -561.98   -225.32      NaN      NaN  -394.47
# 10           NaN  ...        NaN       NaN      NaN      NaN      NaN
# 11           NaN  ...        NaN       NaN      NaN  3915.43      NaN
# 12           NaN  ...        NaN       NaN  6866.86      NaN  2060.14
# 13       -158.61  ...        NaN       NaN      NaN      NaN      NaN
# 14       -5589.7  ...    5723.21       NaN      NaN      NaN      NaN
# 15     -18575.13  ...   -1933.18  -1881.81      NaN      NaN  -394.47
# 16           NaN  ...     509.02    131.89      NaN      NaN   205.16
# 17           NaN  ...        NaN       NaN     41.3    57.86      NaN
# 18         -0.05  ...     -50.87     -0.43      0.0      0.0   -22.68
# 19           NaN  ...    42980.4    776.88      NaN      NaN      NaN
# 20       8568.38  ...     785.48   1383.83  7850.75  3359.75  1326.98
# 21        716.94  ...        NaN       NaN      NaN   411.72      NaN
# 22        176.91  ...      43.85      23.4      NaN    76.99      NaN
# 23           NaN  ...    7461.33     98.82    32.48     9.11      NaN
# 24           NaN  ...        NaN       NaN      NaN      NaN      NaN
# 25       9462.23  ...   51271.06   2282.93  7883.22  3857.57  1326.98
# 26           NaN  ...        NaN       NaN      NaN      NaN   156.21
# 27       9462.23  ...   51271.06   2282.93  7883.22  3857.57  1483.19
#
#    OTHER SECONDARY NON-ENERGY TOTAL SECUNDARIES      TOTAL  Year
# 1          9109.18    5630.96         189790.51  320203.76  2021
# 2          2901.18    1712.36           31674.9   67046.66  2021
# 3           841.83     385.76          17331.46   83055.53  2021
# 4           -25.31       -8.2            -35.62   -4574.51  2021
# 5              NaN        NaN               NaN    1217.87  2021
# 6         11143.23    6949.36         204098.32   298402.5  2021
# 7           7528.3    4710.47          95389.98    2838.23  2021
# 8            -75.3        NaN           46508.5  -14785.66  2021
# 9           -551.3        NaN           9776.97   -9655.28  2021
# 10             NaN     920.49           2354.08    -229.54  2021
# 11             NaN        NaN           3915.43   -3430.59  2021
# 12        -1280.22        NaN            8927.0    -203.06  2021
# 13             NaN        NaN          15486.71     -53.26  2021
# 14         1580.88    -233.26           7431.85     -991.3  2021
# 15        -1906.82    -233.26          -8215.28  -26510.47  2021
# 16         3078.97        NaN           7258.66   24851.84  2021
# 17             NaN        NaN            9456.1    9715.53  2021
# 18           28.88      89.41            130.32     130.14  2021
# 19             NaN        NaN           83272.9    85176.1  2021
# 20         5931.98        NaN          38899.12   82389.66  2021
# 21             NaN        NaN          19827.62   28421.75  2021
# 22             NaN        NaN          12152.68   12548.34  2021
# 23          196.57        NaN           11864.6   15421.69  2021
# 24             NaN        NaN               NaN        NaN  2021
# 25         6128.55        NaN         166016.93  223957.54  2021
# 26             NaN    6626.69          13021.03   13236.97  2021
# 27         6128.55    6626.69         179037.96  237194.52  2021
#
# [27 rows x 25 columns]

# %%
Dict2=Dict.copy()

for k in Dict2.keys():
   # selected_columns = ['SECTOR', 'OIL', 'NATURAL GAS', 'COAL', 'HYDROENERGY', 'GEOTHERMAL',
    #   'NUCLEAR', 'FIREWOOD', 'SUGARCANE AND PRODUCTS', 'OTHER PRIMARY', 'TOTAL PRIMARIES','Year']
    selected_columns = ['SECTOR','KEROSENE/JET FUEL','TOTAL SECUNDARIES','Year']
    Dict2[k]=Dict2[k][selected_columns]
    selected_rows= ['   TRANSPORT ',
       'FINAL CONSUMPTION']
    Dict2[k]=Dict2[k][Dict2[k]['SECTOR'].isin(selected_rows)]
    
    # Concatenate all DataFrames in Dict vertically
    df_conc = pd.concat(Dict2.values(), ignore_index=True)
    
    # Move the column "Year" to the first position
    last_column_name = df_conc.columns[-1]
    # Reorder the columns by concatenating the last column with the rest of the DataFrame
    df_conc = pd.concat([df_conc[last_column_name], df_conc.drop(columns=last_column_name)], axis=1) # Datafames of TOTAL SUPPLY
    df_conc.set_index("Year", inplace=True)
    df_conc.index = df_conc.index.astype(int)
    #df_TC1=df_conc.drop(columns="SECTOR")
    # Set the value "NaN" by Zero
    df_TC1 = df_conc.apply(lambda column: column.fillna(0))
    

df_TC1
# Out:
#                  SECTOR  KEROSENE/JET FUEL  TOTAL SECUNDARIES
# Year
# 1970         TRANSPORT              634.53           12603.81
# 1970  FINAL CONSUMPTION            1137.63           27198.90
# 1971         TRANSPORT              738.51           13788.64
# 1971  FINAL CONSUMPTION            1231.78           30317.01
# 1972         TRANSPORT              840.04           15588.76
# ...                 ...                ...                ...
# 2019  FINAL CONSUMPTION            3311.52          177114.50
# 2020         TRANSPORT             1852.17           77759.66
# 2020  FINAL CONSUMPTION            1856.44          169391.55
# 2021         TRANSPORT             2459.35           83272.90
# 2021  FINAL CONSUMPTION            2463.80          179037.96
#
# [104 rows x 3 columns]

# %%
# Group by Year and SECTOR, and sum the GASOLINE/ALCOHOL and TOTAL SECONDARY values
grouped_df = df_TC1[df_TC1['SECTOR'] != 'FINAL CONSUMPTION'].groupby(['Year', 'SECTOR'])[['KEROSENE/JET FUEL', 'TOTAL SECUNDARIES']].sum().reset_index()

# Pivot the data
pivot_df = grouped_df.pivot(index='Year', columns='SECTOR', values=['KEROSENE/JET FUEL', 'TOTAL SECUNDARIES'])

# Display the result
pivot_df.head()
# Out:
#        KEROSENE/JET FUEL TOTAL SECUNDARIES
# SECTOR        TRANSPORT         TRANSPORT
# Year
# 1970              634.53          12603.81
# 1971              738.51          13788.64
# 1972              840.04          15588.76
# 1973              991.50          18295.77
# 1974             1156.89          20078.21

# %%
# Pivot the data
pivot_df = grouped_df.pivot(index='Year', columns='SECTOR')
pivot_df.columns = pivot_df.columns.map(lambda x: x[0].strip())

# %%
pivot_df.columns = pivot_df.columns.str.strip()

# %%
pivot_df.head()
# Out:
#       KEROSENE/JET FUEL  TOTAL SECUNDARIES
# Year
# 1970             634.53           12603.81
# 1971             738.51           13788.64
# 1972             840.04           15588.76
# 1973             991.50           18295.77
# 1974            1156.89           20078.21

# %%
pivot_df['KEROSENE/JET FUEL/TS'] = pivot_df['KEROSENE/JET FUEL'] / pivot_df['TOTAL SECUNDARIES']

# %%
pivot_df['KEROSENE/JET FUEL/TS'].fillna(0, inplace=True)

# %%
pivot_df
# Out:
#       KEROSENE/JET FUEL  TOTAL SECUNDARIES  KEROSENE/JET FUEL/TS
# Year
# 1970             634.53           12603.81              0.050344
# 1971             738.51           13788.64              0.053559
# 1972             840.04           15588.76              0.053888
# 1973             991.50           18295.77              0.054193
# 1974            1156.89           20078.21              0.057619
# 1975            1247.77           21365.04              0.058402
# 1976            1389.42           23060.13              0.060252
# 1977            1423.80           22703.40              0.062713
# 1978            1459.01           24679.45              0.059118
# 1979            1679.25           26128.47              0.064269
# 1980            1662.65           24969.53              0.066587
# 1981            1878.44           24972.74              0.075220
# 1982            1912.31           25660.13              0.074525
# 1983            1914.78           24658.16              0.077653
# 1984            1695.09           25026.69              0.067731
# 1985            1801.48           26567.90              0.067807
# 1986            1944.09           30242.01              0.064284
# 1987            1968.50           29926.75              0.065777
# 1988            1904.98           30279.04              0.062914
# 1989            2014.77           31825.59              0.063307
# 1990            2000.78           33379.86              0.059940
# 1991            2100.73           34909.45              0.060177
# 1992            1979.05           34995.42              0.056552
# 1993            2086.82           36374.63              0.057370
# 1994            2133.76           38178.68              0.055889
# 1995            2490.11           41786.33              0.059591
# 1996            2658.72           45247.92              0.058759
# 1997            2933.54           46792.99              0.062692
# 1998            3216.28           48690.09              0.066056
# 1999            3057.83           48403.47              0.063174
# 2000            3258.37           47754.50              0.068232
# 2001            3353.50           47975.48              0.069900
# 2002            3161.44           48255.81              0.065514
# 2003            2242.33           46075.98              0.048666
# 2004            2349.38           49901.84              0.047080
# 2005            2546.80           50388.24              0.050544
# 2006            2375.43           51113.55              0.046474
# 2007            2611.82           55231.79              0.047288
# 2008            2803.96           60136.28              0.046627
# 2009            2820.67           60681.48              0.046483
# 2010            3180.02           67003.44              0.047461
# 2011            3559.99           71335.14              0.049905
# 2012            3674.73           77063.02              0.047685
# 2013            3525.02           81244.06              0.043388
# 2014            3566.24           84444.52              0.042232
# 2015            3525.89           82224.85              0.042881
# 2016            3295.24           80368.61              0.041002
# 2017            3287.49           81148.13              0.040512
# 2018            3379.04           80288.42              0.042086
# 2019            3306.72           82915.68              0.039881
# 2020            1852.17           77759.66              0.023819
# 2021            2459.35           83272.90              0.029534

# %%
media = pivot_df['KEROSENE/JET FUEL/TS'].mean()
desviacion_tipica = pivot_df['KEROSENE/JET FUEL/TS'].std()
moda = pivot_df['KEROSENE/JET FUEL/TS'].mode().iloc[0] # La moda puede tener más de un valor, así que tomamos el primero
mediana = pivot_df['KEROSENE/JET FUEL/TS'].median()

print("La media de KEROSENE/JET FUEL/TS es:", media)
print("La desviación típica de KEROSENE/JET FUEL/TS es:", desviacion_tipica)
print("La moda de KEROSENE/JET FUEL/TS es:", moda)
print("La mediana de KEROSENE/JET FUEL/TS es:", mediana)
# Out:
# La media de KEROSENE/JET FUEL/TS es: 0.055529888605227125
# La desviación típica de KEROSENE/JET FUEL/TS es: 0.011348851702588826
# La moda de KEROSENE/JET FUEL/TS es: 0.023819162789549233
# La mediana de KEROSENE/JET FUEL/TS es: 0.057494692874225234

# %%
pivot_df.columns
# Out:
# Index(['KEROSENE/JET FUEL', 'TOTAL SECUNDARIES', 'KEROSENE/JET FUEL/TS'], dtype='object')

# %%
# Cargar los datos económicos y demográficos desde el archivo Excel
economic_demographic_data = pd.read_excel('C:/Users/abomi/Desktop/TFM OK/Mi trabajo/word introduccion + indices/Brasil_indices.xlsx', index_col='Year')

# Unir los DataFrames pivot_df y economic_demographic_data usando el índice (Year)
merged_df = pivot_df.merge(economic_demographic_data, left_index=True, right_index=True)

# Imprimir el DataFrame unido para verificar
print(merged_df)
# Out:
#         KEROSENE/JET FUEL  TOTAL SECUNDARIES  KEROSENE/JET FUEL/TS  Población  \
# Year
# 1970.0             634.53           12603.81              0.050344   96369875
# 1971.0             738.51           13788.64              0.053559   98766288
# 1972.0             840.04           15588.76              0.053888  101194394
# 1973.0             991.50           18295.77              0.054193  103666904
# 1974.0            1156.89           20078.21              0.057619  106167372
# 1975.0            1247.77           21365.04              0.058402  108700515
# 1976.0            1389.42           23060.13              0.060252  111286504
# 1977.0            1423.80           22703.40              0.062713  113939886
# 1978.0            1459.01           24679.45              0.059118  116664382
# 1979.0            1679.25           26128.47              0.064269  119447303
# 1980.0            1662.65           24969.53              0.066587  122288383
# 1981.0            1878.44           24972.74              0.075220  125168060
# 1982.0            1912.31           25660.13              0.074525  128065095
# 1983.0            1914.78           24658.16              0.077653  130977370
# 1984.0            1695.09           25026.69              0.067731  133888775
# 1985.0            1801.48           26567.90              0.067807  136783180
# 1986.0            1944.09           30242.01              0.064284  139643355
# 1987.0            1968.50           29926.75              0.065777  142466264
# 1988.0            1904.98           30279.04              0.062914  145253973
# 1989.0            2014.77           31825.59              0.063307  148003411
# 1990.0            2000.78           33379.86              0.059940  150706446
# 1991.0            2100.73           34909.45              0.060177  153336445
# 1992.0            1979.05           34995.42              0.056552  155900790
# 1993.0            2086.82           36374.63              0.057370  158440875
# 1994.0            2133.76           38178.68              0.055889  160980472
# 1995.0            2490.11           41786.33              0.059591  163515328
# 1996.0            2658.72           45247.92              0.058759  166037122
# 1997.0            2933.54           46792.99              0.062692  168546707
# 1998.0            3216.28           48690.09              0.066056  171039804
# 1999.0            3057.83           48403.47              0.063174  173486281
# 2000.0            3258.37           47754.50              0.068232  175873720
# 2001.0            3353.50           47975.48              0.069900  178211881
# 2002.0            3161.44           48255.81              0.065514  180476685
# 2003.0            2242.33           46075.98              0.048666  182629278
# 2004.0            2349.38           49901.84              0.047080  184722043
# 2005.0            2546.80           50388.24              0.050544  186797334
# 2006.0            2375.43           51113.55              0.046474  188820682
# 2007.0            2611.82           55231.79              0.047288  190779453
# 2008.0            2803.96           60136.28              0.046627  192672317
# 2009.0            2820.67           60681.48              0.046483  194517549
# 2010.0            3180.02           67003.44              0.047461  196353492
# 2011.0            3559.99           71335.14              0.049905  198185302
# 2012.0            3674.73           77063.02              0.047685  199977707
# 2013.0            3525.02           81244.06              0.043388  201721767
# 2014.0            3566.24           84444.52              0.042232  203459650
# 2015.0            3525.89           82224.85              0.042881  205188205
# 2016.0            3295.24           80368.61              0.041002  206859578
# 2017.0            3287.49           81148.13              0.040512  208504960
# 2018.0            3379.04           80288.42              0.042086  210166592
# 2019.0            3306.72           82915.68              0.039881  211782878
# 2020.0            1852.17           77759.66              0.023819  213196304
# 2021.0            2459.35           83272.90              0.029534  214326223
#
#                  PIB  Crecimiento población anual  Tasa de natalidad  \
# Year
# 1970.0  4.232766e+10                     0.025207              4.972
# 1971.0  4.886983e+10                     0.024867              4.857
# 1972.0  5.843486e+10                     0.024584              4.746
# 1973.0  8.359228e+10                     0.024433              4.646
# 1974.0  1.097945e+11                     0.024120              4.502
# 1975.0  1.292036e+11                     0.023860              4.415
# 1976.0  1.531689e+11                     0.023790              4.339
# 1977.0  1.763441e+11                     0.023843              4.267
# 1978.0  2.002786e+11                     0.023912              4.195
# 1979.0  2.213382e+11                     0.023854              4.120
# 1980.0  2.373935e+11                     0.023785              4.037
# 1981.0  2.580152e+11                     0.023548              3.943
# 1982.0  2.713141e+11                     0.023145              3.838
# 1983.0  1.896565e+11                     0.022741              3.723
# 1984.0  1.883400e+11                     0.022228              3.600
# 1985.0  2.108798e+11                     0.021618              3.471
# 1986.0  2.564809e+11                     0.020910              3.342
# 1987.0  2.830568e+11                     0.020215              3.234
# 1988.0  3.078819e+11                     0.019568              3.112
# 1989.0  4.129908e+11                     0.018928              3.010
# 1990.0  4.649891e+11                     0.018263              2.905
# 1991.0  4.077291e+11                     0.017451              2.815
# 1992.0  3.905666e+11                     0.016724              2.719
# 1993.0  4.382995e+11                     0.016293              2.672
# 1994.0  5.462297e+11                     0.016029              2.617
# 1995.0  7.693333e+11                     0.015746              2.579
# 1996.0  8.504264e+11                     0.015422              2.516
# 1997.0  8.832065e+11                     0.015115              2.465
# 1998.0  8.637110e+11                     0.014792              2.409
# 1999.0  5.996421e+11                     0.014304              2.331
# 2000.0  6.554482e+11                     0.013762              2.255
# 2001.0  5.599837e+11                     0.013295              2.183
# 2002.0  5.097953e+11                     0.012708              2.103
# 2003.0  5.582337e+11                     0.011927              2.023
# 2004.0  6.692893e+11                     0.011459              2.002
# 2005.0  8.916338e+11                     0.011235              1.974
# 2006.0  1.107627e+12                     0.010832              1.927
# 2007.0  1.397114e+12                     0.010374              1.881
# 2008.0  1.695855e+12                     0.009922              1.842
# 2009.0  1.666996e+12                     0.009577              1.825
# 2010.0  2.208838e+12                     0.009438              1.810
# 2011.0  2.616157e+12                     0.009329              1.800
# 2012.0  2.465228e+12                     0.009044              1.767
# 2013.0  2.472819e+12                     0.008721              1.748
# 2014.0  2.456044e+12                     0.008615              1.767
# 2015.0  1.802212e+12                     0.008496              1.777
# 2016.0  1.795693e+12                     0.008146              1.709
# 2017.0  2.063515e+12                     0.007954              1.736
# 2018.0  1.916934e+12                     0.007969              1.749
# 2019.0  1.873288e+12                     0.007690              1.703
# 2020.0  1.476107e+12                     0.006674              1.649
# 2021.0  1.649623e+12                     0.005300              1.641
#
#         Tasa inflacion  Tasas de muerte/1000 personas  \
# Year
# 1970.0       24.750000                         10.820
# 1971.0       15.550000                         10.595
# 1972.0       18.970000                         10.367
# 1973.0       15.240000                         10.157
# 1974.0       34.520000                          9.954
# 1975.0       29.830000                          9.744
# 1976.0       18.220000                          9.568
# 1977.0        6.770000                          9.392
# 1978.0        6.920000                          9.203
# 1979.0       77.240000                          8.989
# 1980.0      110.160000                          8.779
# 1981.0      101.725073                          8.558
# 1982.0      100.543359                          8.346
# 1983.0      135.027682                          8.153
# 1984.0      192.121733                          7.970
# 1985.0      225.989665                          7.796
# 1986.0      147.142826                          7.615
# 1987.0      228.336163                          7.447
# 1988.0      629.114509                          7.310
# 1989.0     1430.723725                          7.165
# 1990.0     2947.732772                          7.158
# 1991.0      432.786662                          7.068
# 1992.0      951.962053                          6.951
# 1993.0     1927.380790                          6.855
# 1994.0     2075.888398                          6.740
# 1995.0       66.007034                          6.685
# 1996.0       15.757666                          6.564
# 1997.0        6.926713                          6.488
# 1998.0        3.195076                          6.429
# 1999.0        4.858447                          6.386
# 2000.0        7.044141                          6.399
# 2001.0        6.840359                          6.303
# 2002.0        8.450164                          6.329
# 2003.0       14.714920                          6.313
# 2004.0        6.597185                          6.258
# 2005.0        6.869537                          6.106
# 2006.0        4.183568                          6.123
# 2007.0        3.641273                          6.119
# 2008.0        5.678594                          6.106
# 2009.0        4.888035                          6.155
# 2010.0        5.038727                          6.199
# 2011.0        6.636450                          6.283
# 2012.0        5.403499                          6.340
# 2013.0        6.204311                          6.310
# 2014.0        6.329040                          6.272
# 2015.0        9.029901                          6.433
# 2016.0        8.739144                          6.538
# 2017.0        3.446373                          6.493
# 2018.0        3.664850                          6.516
# 2019.0        3.732976                          6.572
# 2020.0        3.211768                          7.420
# 2021.0        8.301660                          8.326
#
#         Consumo per capita energetico  ...  Peso Natural gas  Peso Coal  \
# Year                                   ...
# 1970.0                       0.000693  ...          0.002680   0.033276
# 1971.0                       0.000710  ...          0.004022   0.033071
# 1972.0                       0.000742  ...          0.004108   0.030332
# 1973.0                       0.000791  ...          0.004301   0.027472
# 1974.0                       0.000825  ...          0.006214   0.027218
# 1975.0                       0.000839  ...          0.006554   0.030909
# 1976.0                       0.000862  ...          0.007046   0.034042
# 1977.0                       0.000873  ...          0.008129   0.039854
# 1978.0                       0.000903  ...          0.009214   0.040933
# 1979.0                       0.000939  ...          0.009173   0.042844
# 1980.0                       0.000936  ...          0.010112   0.045639
# 1981.0                       0.000877  ...          0.009759   0.047510
# 1982.0                       0.000874  ...          0.012888   0.048820
# 1983.0                       0.000879  ...          0.016797   0.052328
# 1984.0                       0.000914  ...          0.019333   0.059565
# 1985.0                       0.000950  ...          0.022713   0.067995
# 1986.0                       0.000978  ...          0.026048   0.067917
# 1987.0                       0.000999  ...          0.028285   0.065469
# 1988.0                       0.000992  ...          0.029520   0.065293
# 1989.0                       0.000987  ...          0.030877   0.064051
# 1990.0                       0.001005  ...          0.027654   0.092609
# 1991.0                       0.001008  ...          0.027679   0.099055
# 1992.0                       0.000996  ...          0.029162   0.095643
# 1993.0                       0.001005  ...          0.030936   0.097172
# 1994.0                       0.001037  ...          0.031186   0.094528
# 1995.0                       0.001050  ...          0.032916   0.098665
# 1996.0                       0.001088  ...          0.034268   0.098416
# 1997.0                       0.001078  ...          0.038573   0.068177
# 1998.0                       0.001090  ...          0.039002   0.064890
# 1999.0                       0.001142  ...          0.040121   0.092658
# 2000.0                       0.001143  ...          0.051979   0.095477
# 2001.0                       0.001147  ...          0.061677   0.090414
# 2002.0                       0.001105  ...          0.071250   0.059167
# 2003.0                       0.001109  ...          0.073510   0.056428
# 2004.0                       0.001155  ...          0.083499   0.059611
# 2005.0                       0.001172  ...          0.088499   0.057574
# 2006.0                       0.001195  ...          0.087481   0.055387
# 2007.0                       0.001248  ...          0.086368   0.056188
# 2008.0                       0.001307  ...          0.096433   0.054184
# 2009.0                       0.001246  ...          0.082977   0.047515
# 2010.0                       0.001361  ...          0.102623   0.051759
# 2011.0                       0.001366  ...          0.098293   0.054285
# 2012.0                       0.001420  ...          0.111605   0.052179
# 2013.0                       0.001472  ...          0.124229   0.053649
# 2014.0                       0.001502  ...          0.134485   0.056161
# 2015.0                       0.001460  ...          0.136826   0.056116
# 2016.0                       0.001400  ...          0.129313   0.055160
# 2017.0                       0.001414  ...          0.138044   0.057516
# 2018.0                       0.001384  ...          0.129773   0.056080
# 2019.0                       0.001394  ...          0.128317   0.052210
# 2020.0                       0.001346  ...          0.107513   0.046214
# 2021.0                       0.001392  ...          0.127954   0.056028
#
#         Peso Hydroenergy       Nuclear  Firewood  Sugarcane and products  \
# Year
# 1970.0          0.050933  0.000000e+00  0.474146                0.053600
# 1971.0          0.053517  0.000000e+00  0.458372                0.055364
# 1972.0          0.057178  0.000000e+00  0.421840                0.056411
# 1973.0          0.059777  0.000000e+00  0.383140                0.055787
# 1974.0          0.064438  0.000000e+00  0.372043                0.052712
# 1975.0          0.067234  0.000000e+00  0.358707                0.045220
# 1976.0          0.074353  0.000000e+00  0.332579                0.049529
# 1977.0          0.080596  0.000000e+00  0.309126                0.065579
# 1978.0          0.082901  0.000000e+00  0.279643                0.068722
# 1979.0          0.089301  0.000000e+00  0.270657                0.073549
# 1980.0          0.096794  0.000000e+00  0.271504                0.081241
# 1981.0          0.099100  0.000000e+00  0.268128                0.089888
# 1982.0          0.105321 -1.736173e-07  0.252690                0.105385
# 1983.0          0.108194  0.000000e+00  0.251202                0.128414
# 1984.0          0.108541  7.518367e-04  0.252681                0.127274
# 1985.0          0.111475  7.709585e-04  0.239357                0.138909
# 1986.0          0.111731  3.049453e-05  0.233454                0.122951
# 1987.0          0.109128  2.104555e-04  0.224181                0.142070
# 1988.0          0.117619  1.288541e-04  0.223795                0.130789
# 1989.0          0.120276  3.739607e-04  0.225245                0.126315
# 1990.0          0.117396  4.545926e-04  0.221798                0.121898
# 1991.0          0.123286  3.079889e-04  0.206861                0.132317
# 1992.0          0.126251  2.628938e-04  0.194093                0.131932
# 1993.0          0.131483  1.052777e-04  0.189867                0.126084
# 1994.0          0.131468  1.625682e-05  0.184271                0.138028
# 1995.0          0.137243  6.471339e-04  0.172077                0.136936
# 1996.0          0.136422  5.382951e-04  0.154340                0.139708
# 1997.0          0.142415  7.235661e-04  0.130313                0.154398
# 1998.0          0.143434  9.564537e-04  0.123303                0.144339
# 1999.0          0.134905  8.554524e-04  0.139439                0.131624
# 2000.0          0.137408  9.314124e-03  0.142439                0.104466
# 2001.0          0.117264  1.881781e-02  0.134418                0.116103
# 2002.0          0.127248  1.871613e-02  0.123871                0.131061
# 2003.0          0.130478  1.708976e-02  0.130604                0.140967
# 2004.0          0.128937  1.419718e-02  0.131691                0.137590
# 2005.0          0.132626  1.137199e-02  0.129716                0.143657
# 2006.0          0.132544  1.586606e-02  0.125910                0.155772
# 2007.0          0.135288  1.354772e-02  0.120370                0.170755
# 2008.0          0.127723  1.466747e-02  0.117454                0.181540
# 2009.0          0.140196  1.411366e-02  0.102606                0.187328
# 2010.0          0.135213  1.477195e-02  0.101352                0.191108
# 2011.0          0.143714  1.596089e-02  0.101423                0.169394
# 2012.0          0.133768  1.564486e-02  0.095970                0.169036
# 2013.0          0.119365  1.428545e-02  0.087065                0.175106
# 2014.0          0.110406  1.381509e-02  0.085734                0.169869
# 2015.0          0.108165  1.346142e-02  0.085737                0.176943
# 2016.0          0.119096  1.506814e-02  0.083964                0.184806
# 2017.0          0.116065  1.496183e-02  0.088868                0.181554
# 2018.0          0.120905  1.480016e-02  0.092205                0.184583
# 2019.0          0.122271  1.505710e-02  0.091925                0.189541
# 2020.0          0.121373  1.308404e-02  0.091541                0.198635
# 2021.0          0.109559  1.350166e-02  0.091582                0.174131
#
#            Otros  TOTAL   Penet_energ_renovable  Huella_carbono
# Year
# 1970.0  0.003323    1.0                0.525079        0.474921
# 1971.0  0.003355    1.0                0.511889        0.488111
# 1972.0  0.003956    1.0                0.479018        0.520982
# 1973.0  0.003731    1.0                0.442917        0.557083
# 1974.0  0.003982    1.0                0.436481        0.563519
# 1975.0  0.003923    1.0                0.425941        0.574059
# 1976.0  0.004294    1.0                0.406932        0.593068
# 1977.0  0.004718    1.0                0.389723        0.610277
# 1978.0  0.005261    1.0                0.362545        0.637455
# 1979.0  0.007322    1.0                0.359958        0.640042
# 1980.0  0.008822    1.0                0.368298        0.631702
# 1981.0  0.009648    1.0                0.367228        0.632772
# 1982.0  0.010146    1.0                0.358010        0.641990
# 1983.0  0.009923    1.0                0.359395        0.640605
# 1984.0  0.010801    1.0                0.361221        0.638779
# 1985.0  0.011509    1.0                0.350832        0.649168
# 1986.0  0.012609    1.0                0.345185        0.654815
# 1987.0  0.012733    1.0                0.333309        0.666691
# 1988.0  0.013757    1.0                0.341414        0.658586
# 1989.0  0.013655    1.0                0.345522        0.654478
# 1990.0  0.014048    1.0                0.339194        0.660806
# 1991.0  0.015398    1.0                0.330147        0.669853
# 1992.0  0.018052    1.0                0.320344        0.679656
# 1993.0  0.019419    1.0                0.321351        0.678649
# 1994.0  0.018930    1.0                0.315739        0.684261
# 1995.0  0.018382    1.0                0.309320        0.690680
# 1996.0  0.018439    1.0                0.290762        0.709238
# 1997.0  0.019544    1.0                0.272728        0.727272
# 1998.0  0.019785    1.0                0.266737        0.733263
# 1999.0  0.021261    1.0                0.274344        0.725656
# 2000.0  0.023307    1.0                0.279848        0.720152
# 2001.0  0.023581    1.0                0.251682        0.748318
# 2002.0  0.026189    1.0                0.251119        0.748881
# 2003.0  0.028664    1.0                0.261082        0.738918
# 2004.0  0.027455    1.0                0.260627        0.739373
# 2005.0  0.029395    1.0                0.262341        0.737659
# 2006.0  0.024198    1.0                0.258455        0.741545
# 2007.0  0.031482    1.0                0.255658        0.744342
# 2008.0  0.034186    1.0                0.245178        0.754823
# 2009.0  0.039059    1.0                0.242802        0.757198
# 2010.0  0.040841    1.0                0.236565        0.763435
# 2011.0  0.043504    1.0                0.245137        0.754863
# 2012.0  0.042729    1.0                0.229738        0.770262
# 2013.0  0.043729    1.0                0.206429        0.793571
# 2014.0  0.048915    1.0                0.196140        0.803860
# 2015.0  0.056219    1.0                0.193902        0.806098
# 2016.0  0.064442    1.0                0.203060        0.796940
# 2017.0  0.070579    1.0                0.204934        0.795066
# 2018.0  0.078554    1.0                0.213109        0.786891
# 2019.0  0.080701    1.0                0.214196        0.785804
# 2020.0  0.088656    1.0                0.212914        0.787086
# 2021.0  0.098690    1.0                0.201141        0.798859
#
# [52 rows x 22 columns]

# %%
# Verificar valores faltantes
missing_values = merged_df.isnull().sum()
print("Valores faltantes por columna:")
print(missing_values)
# Out:
# Valores faltantes por columna:
# KEROSENE/JET FUEL                0
# TOTAL SECUNDARIES                0
# KEROSENE/JET FUEL/TS             0
# Población                        0
# PIB                              0
# Crecimiento población anual      0
# Tasa de natalidad                0
# Tasa inflacion                   0
# Tasas de muerte/1000 personas    0
# Consumo per capita energetico    0
# tasa de crecimiento              1
# Peso Petróleo                    0
# Peso Natural gas                 0
# Peso Coal                        0
# Peso Hydroenergy                 0
# Nuclear                          0
# Firewood                         0
# Sugarcane and products           0
# Otros                            0
# TOTAL                            0
#  Penet_energ_renovable           0
# Huella_carbono                   0
# dtype: int64

# %%
# Verificar si los datos son numéricos
non_numeric_columns = merged_df.select_dtypes(exclude=[np.number]).columns
print("Columnas no numéricas:")
print(non_numeric_columns)
# Out:
# Columnas no numéricas:
# Index(['Población'], dtype='object')

# %%
# Convertir la columna 'Población' a numérica en el DataFrame merged_df
merged_df['Población'] = pd.to_numeric(merged_df['Población'], errors='coerce')

# Verificar el tipo de dato después de la conversión
print(merged_df.dtypes)
# Out:
# KEROSENE/JET FUEL                float64
# TOTAL SECUNDARIES                float64
# KEROSENE/JET FUEL/TS             float64
# Población                          int64
# PIB                              float64
# Crecimiento población anual      float64
# Tasa de natalidad                float64
# Tasa inflacion                   float64
# Tasas de muerte/1000 personas    float64
# Consumo per capita energetico    float64
# Peso Petróleo                    float64
# Peso Natural gas                 float64
# Peso Coal                        float64
# Peso Hydroenergy                 float64
# Nuclear                          float64
# Firewood                         float64
# Sugarcane and products           float64
# Otros                            float64
# TOTAL                            float64
#  Penet_energ_renovable           float64
# Huella_carbono                   float64
# dtype: object

# %%
columns_to_drop = ['Tasas de muerte/1000 personas', 'tasa de crecimiento', 'Consumo per capita energetico', 'Peso Petróleo', 'Peso Natural gas', 
                   'Peso Coal', 'Peso Hydroenergy', 'Nuclear', 'Firewood', 'Sugarcane and products', 'Otros', 'TOTAL', 
                   ' Penet_energ_renovable', 'Huella_carbono', 'Crecimiento población anual']

merged_df.drop(columns=columns_to_drop, inplace=True)

# Verificar el DataFrame después de eliminar las columnas
print(merged_df.head())
# Out:
#         KEROSENE/JET FUEL  TOTAL SECUNDARIES  KEROSENE/JET FUEL/TS  Población  \
# Year
# 1970.0             634.53           12603.81              0.050344   96369875
# 1971.0             738.51           13788.64              0.053559   98766288
# 1972.0             840.04           15588.76              0.053888  101194394
# 1973.0             991.50           18295.77              0.054193  103666904
# 1974.0            1156.89           20078.21              0.057619  106167372
#
#                  PIB  Tasa de natalidad  Tasa inflacion
# Year
# 1970.0  4.232766e+10              4.972           24.75
# 1971.0  4.886983e+10              4.857           15.55
# 1972.0  5.843486e+10              4.746           18.97
# 1973.0  8.359228e+10              4.646           15.24
# 1974.0  1.097945e+11              4.502           34.52

# %%
# Escalar las variables independientes
columns_to_scale = [ 'TOTAL SECUNDARIES', 'Población', 'PIB',
                    'Tasa de natalidad', 'Tasa inflacion']

mean_values = merged_df[columns_to_scale].mean()
std_values = merged_df[columns_to_scale].std()

scaled_data = (merged_df[columns_to_scale] - mean_values) / std_values

scaled_df = pd.concat([scaled_data, merged_df.drop(columns=columns_to_scale)], axis=1)

# Definir las variables de entrada (X) y la variable objetivo (y)
columnas_a_eliminar = ['KEROSENE/JET FUEL/TS', 'KEROSENE/JET FUEL']
X = scaled_df.drop(columns=columnas_a_eliminar)
y = scaled_df['KEROSENE/JET FUEL/TS']

# Dividir los datos en entrenamiento y prueba
train_mask = (scaled_df.index <= 2010)
test_mask = (scaled_df.index >= 2011)

X_train = X[train_mask]
y_train = y[train_mask]

X_test = X[test_mask]
y_test = y[test_mask]

# Imprimir las dimensiones de los conjuntos de entrenamiento y prueba
print("Dimensiones del conjunto de entrenamiento:")
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)

print("\nDimensiones del conjunto de prueba:")
print("X_test:", X_test.shape)
print("y_test:", y_test.shape)
# Out:
# Dimensiones del conjunto de entrenamiento:
# X_train: (41, 5)
# y_train: (41,)
#
# Dimensiones del conjunto de prueba:
# X_test: (11, 5)
# y_test: (11,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Crear una instancia del modelo de regresión lineal
model = LinearRegression()

# Entrenar el modelo con los datos de entrenamiento
model.fit(X_train, y_train)

# Realizar predicciones en los datos de prueba
y_pred = model.predict(X_test)

# Comparar las predicciones con los valores reales usando el error cuadrático medio (MSE)
mse = mean_squared_error(y_test, y_pred)

print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 6.503785528929198e-05

# %%
# Filtrar datos reales y predichos para los años 2011 a 2021
actual_y_2011_2021 = merged_df.loc[(merged_df.index >= 2011) & (merged_df.index <= 2021), 'KEROSENE/JET FUEL/TS']
predicted_y_2011_2021 = y_pred[(X_test.index >= 2011) & (X_test.index <= 2021)]

# Calcular el error cuadrático medio (MSE) para los años 2011 a 2021
mse_2011_2021 = mean_squared_error(actual_y_2011_2021, predicted_y_2011_2021)

# Calcular el error para cada año en el período 2011-2021
for year in range(2011, 2022):
    actual_value = actual_y_2011_2021[year]
    predicted_value = predicted_y_2011_2021[year - 2011]
    error = actual_value - predicted_value
    print(f"Año {year}: Valor real = {actual_value:.2f}, Valor predicho = {predicted_value:.2f}, Error = {error:.2f}")

print("Mean Squared Error (2011-2021):", mse_2011_2021)
# Out:
# Año 2011: Valor real = 0.05, Valor predicho = 0.04, Error = 0.01
# Año 2012: Valor real = 0.05, Valor predicho = 0.04, Error = 0.01
# Año 2013: Valor real = 0.04, Valor predicho = 0.04, Error = 0.00
# Año 2014: Valor real = 0.04, Valor predicho = 0.04, Error = 0.00
# Año 2015: Valor real = 0.04, Valor predicho = 0.05, Error = -0.00
# Año 2016: Valor real = 0.04, Valor predicho = 0.04, Error = -0.00
# Año 2017: Valor real = 0.04, Valor predicho = 0.04, Error = 0.00
# Año 2018: Valor real = 0.04, Valor predicho = 0.04, Error = 0.00
# Año 2019: Valor real = 0.04, Valor predicho = 0.04, Error = 0.00
# Año 2020: Valor real = 0.02, Valor predicho = 0.04, Error = -0.02
# Año 2021: Valor real = 0.03, Valor predicho = 0.04, Error = -0.01
# Mean Squared Error (2011-2021): 6.503785528929198e-05

# %%
import matplotlib.pyplot as plt

# Filtrar datos reales y predichos para los años 2011 a 2021
actual_y_2011_2021 = merged_df.loc[(merged_df.index >= 2011) & (merged_df.index <= 2021), 'KEROSENE/JET FUEL/TS']
predicted_y_2011_2021 = y_pred[(X_test.index >= 2011) & (X_test.index <= 2021)]

# Crear un gráfico comparando los valores reales y predichos
plt.figure(figsize=(10, 6))
plt.plot(actual_y_2011_2021.index, actual_y_2011_2021.values, label='Real')
plt.plot(actual_y_2011_2021.index, predicted_y_2011_2021, label='Predicho')
plt.title('Comparación entre Valores Reales y Predichos (2011-2021)')
plt.xlabel('Año')
plt.ylabel('KEROSENE/JET FUEL/TS')
plt.legend()
plt.grid(True)

# Ajustar el rango del eje y de 0 a 1
plt.ylim(0, 1)

plt.show()

# %%
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# Ajustando el modelo ARIMA
model = ARIMA(y_train, order=(5, 1, 0))
fit_model = model.fit()

# Realizar predicciones en los datos de prueba
y_pred_arima = fit_model.predict(start=len(y_train), end=len(y_train) + len(y_test) - 1, typ='levels')

# Calcular el error cuadrático medio (MSE)
mse_arima = mean_squared_error(y_test, y_pred_arima)

# Filtrar datos reales para los años 2011 a 2021
actual_y_2011_2021 = scaled_df.loc[(scaled_df.index >= 2011) & (scaled_df.index <= 2021), 'KEROSENE/JET FUEL/TS']
# Out:
# C:\Users\abomi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\abomi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\abomi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\abomi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# Crear un gráfico comparando los valores reales y predichos por ARIMA
plt.figure(figsize=(10, 6))
plt.plot(actual_y_2011_2021.index, actual_y_2011_2021.values, label='Real')
plt.plot(actual_y_2011_2021.index, y_pred_arima, label='Predicho (ARIMA)')
plt.title('Comparación entre Valores Reales y Predichos (2011-2021) por ARIMA')
plt.xlabel('Año')
plt.ylabel('KEROSENE/JET FUEL/TS (Escalado)')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()

print("Mean Squared Error (ARIMA):", mse_arima)
# Out:
# Mean Squared Error (ARIMA): 0.00011418681842072967

# %%
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error

# Ajustar el modelo de suavizado exponencial con tendencia aditiva
model = ExponentialSmoothing(y_train, trend='add')
fit_model = model.fit()

# Realizar predicciones en los datos de prueba
y_pred_exp_smooth = fit_model.predict(start=len(y_train), end=len(y_train) + len(y_test) - 1)

# Filtrar datos reales para los años 2011 a 2021
actual_y_2011_2021 = scaled_df.loc[(scaled_df.index >= 2011) & (scaled_df.index <= 2021), 'KEROSENE/JET FUEL/TS']

# Calcular el error cuadrático medio (MSE)
mse_exp_smooth = mean_squared_error(actual_y_2011_2021, y_pred_exp_smooth)

# Comparar valores predichos con valores reales
plt.figure(figsize=(10, 6))
plt.plot(actual_y_2011_2021.index, actual_y_2011_2021, label='Valor Real')
plt.plot(actual_y_2011_2021.index, y_pred_exp_smooth, label='Valor Predicho (Exp. Smooth)')
plt.xlabel('Año')
plt.ylabel('KEROSENE-JET FUEL/TS')
plt.title('Comparación de Valores Predichos y Reales (Exp. Smooth)')
plt.legend()
plt.ylim(0, 1)  # Establecer límites del eje y entre 0 y 1
plt.show()

print("Mean Squared Error (Exp. Smooth):", mse_exp_smooth)
# Out:
# C:\Users\abomi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\abomi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Mean Squared Error (Exp. Smooth): 4.47718872357088e-05

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Crear características polinomiales
poly = PolynomialFeatures(degree=3)
X_poly = poly.fit_transform(X_train)

# Crear un modelo de regresión polinomial
model = LinearRegression()
model.fit(X_poly, y_train)

# Realizar predicciones en los datos de prueba
X_test_poly = poly.transform(X_test)
y_pred_poly = model.predict(X_test_poly)

# Filtrar datos reales para los años 2011 a 2021
actual_y_2011_2021 = scaled_df.loc[(scaled_df.index >= 2011) & (scaled_df.index <= 2021), 'KEROSENE/JET FUEL/TS']

# Calcular el error cuadrático medio (MSE)
mse_poly = mean_squared_error(actual_y_2011_2021, y_pred_poly)

# Comparar valores predichos con valores reales
plt.figure(figsize=(10, 6))
plt.plot(actual_y_2011_2021.index, actual_y_2011_2021, label='Valor Real')
plt.plot(actual_y_2011_2021.index, y_pred_poly, label='Valor Predicho (Polynomial)')
plt.xlabel('Año')
plt.ylabel('KEROSENE/JET FUEL/TS')
plt.title('Comparación de Valores Predichos y Reales (Polynomial)')
plt.legend()
plt.ylim(0, 1)  # Establecer límites del eje y entre 0 y 1
plt.show()

print("Mean Squared Error (Polynomial):", mse_poly)
# Out:
# Mean Squared Error (Polynomial): 11.712873264026694

# %%
from sklearn.linear_model import Lasso
import numpy as np

# Crear un modelo Lasso
lasso_model = Lasso(alpha=0.1)
lasso_model.fit(X_train, y_train)

# Realizar predicciones en los datos de prueba
y_pred_lasso = lasso_model.predict(X_test)

# Filtrar datos reales para los años 2011 a 2021
actual_y_2011_2021 = scaled_df.loc[(scaled_df.index >= 2011) & (scaled_df.index <= 2021), 'KEROSENE/JET FUEL/TS']

# Calcular el error cuadrático medio (MSE)
mse_lasso = mean_squared_error(actual_y_2011_2021, y_pred_lasso)

# Comparar valores predichos con valores reales
plt.figure(figsize=(10, 6))
plt.plot(actual_y_2011_2021.index, actual_y_2011_2021, label='Valor Real')
plt.plot(actual_y_2011_2021.index, y_pred_lasso, label='Valor Predicho (Lasso)')
plt.xlabel('Año')
plt.ylabel('KEROSENE/JET FUEL/TS')
plt.title('Comparación de Valores Predichos y Reales (Lasso)')
plt.legend()
plt.ylim(0, 1)  # Establecer límites del eje y entre 0 y 1
plt.show()

print("Mean Squared Error (Lasso):", mse_lasso)
# Out:
# Mean Squared Error (Lasso): 0.0004255230447069341

# %%
from sklearn.linear_model import Ridge
import numpy as np

# Crear un modelo Ridge
ridge_model = Ridge(alpha=0.1)
ridge_model.fit(X_train, y_train)

# Realizar predicciones en los datos de prueba
y_pred_ridge = ridge_model.predict(X_test)

# Filtrar datos reales para los años 2011 a 2021
actual_y_2011_2021 = scaled_df.loc[(scaled_df.index >= 2011) & (scaled_df.index <= 2021), 'KEROSENE/JET FUEL/TS']

# Calcular el error cuadrático medio (MSE)
mse_ridge = mean_squared_error(actual_y_2011_2021, y_pred_ridge)

# Comparar valores predichos con valores reales
plt.figure(figsize=(10, 6))
plt.plot(actual_y_2011_2021.index, actual_y_2011_2021, label='Valor Real')
plt.plot(actual_y_2011_2021.index, y_pred_ridge, label='Valor Predicho (Ridge)')
plt.xlabel('Año')
plt.ylabel('KEROSENE/JET FUEL/TS')
plt.title('Comparación de Valores Predichos y Reales (Ridge)')
plt.legend()
plt.ylim(0, 1)  # Establecer límites del eje y entre 0 y 1
plt.show()

print("Mean Squared Error (Ridge):", mse_ridge)
# Out:
# Mean Squared Error (Ridge): 0.000130748196808337

# %%
from sklearn.linear_model import ElasticNet
import numpy as np

# Crear un modelo ElasticNet
elastic_model = ElasticNet(alpha=0.1, l1_ratio=0.5)
elastic_model.fit(X_train, y_train)

# Realizar predicciones en los datos de prueba
y_pred_elastic = elastic_model.predict(X_test)

# Filtrar datos reales para los años 2011 a 2021
actual_y_2011_2021 = scaled_df.loc[(scaled_df.index >= 2011) & (scaled_df.index <= 2021), 'KEROSENE/JET FUEL/TS']

# Calcular el error cuadrático medio (MSE)
mse_elastic = mean_squared_error(actual_y_2011_2021, y_pred_elastic)

# Comparar valores predichos con valores reales
plt.figure(figsize=(10, 6))
plt.plot(actual_y_2011_2021.index, actual_y_2011_2021, label='Valor Real')
plt.plot(actual_y_2011_2021.index, y_pred_elastic, label='Valor Predicho (ElasticNet)')
plt.xlabel('Año')
plt.ylabel('KEROSENE/JET FUEL/TS')
plt.title('Comparación de Valores Predichos y Reales (ElasticNet)')
plt.legend()
plt.ylim(0, 1)  # Establecer límites del eje y entre 0 y 1
plt.show()

print("Mean Squared Error (ElasticNet):", mse_elastic)
# Out:
# Mean Squared Error (ElasticNet): 0.0004255230447069341

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
import numpy as np

# Crear un modelo SARIMA
model = SARIMAX(y_train, order=(5, 1, 0), seasonal_order=(0, 1, 1, 12))
fit_model = model.fit(disp=False)

# Realizar predicciones en los datos de prueba
y_pred_sarima = fit_model.predict(start=len(y_train), end=len(y_train) + len(y_test) - 1)

# Filtrar datos reales para los años 2011 a 2021
actual_y_2011_2021 = scaled_df.loc[(scaled_df.index >= 2011) & (scaled_df.index <= 2021), 'KEROSENE/JET FUEL/TS']

# Calcular el error cuadrático medio (MSE)
mse_sarima = mean_squared_error(actual_y_2011_2021, y_pred_sarima)

# Comparar valores predichos con valores reales
plt.figure(figsize=(10, 6))
plt.plot(actual_y_2011_2021.index, actual_y_2011_2021, label='Valor Real')
plt.plot(actual_y_2011_2021.index, y_pred_sarima, label='Valor Predicho (SARIMA)')
plt.xlabel('Año')
plt.ylabel('KEROSENE/JET FUEL/TS')
plt.title('Comparación de Valores Predichos y Reales (SARIMA)')
plt.legend()
plt.ylim(0, 1)  # Establecer límites del eje y entre 0 y 1
plt.show()

print("Mean Squared Error (SARIMA):", mse_sarima)
# Out:
# C:\Users\abomi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\abomi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\abomi\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# C:\Users\abomi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Mean Squared Error (SARIMA): 3.935569396245973e-05

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing
import numpy as np

# Crear un modelo ETS
ets_model = ExponentialSmoothing(y_train, trend='add', seasonal='add', seasonal_periods=12)

# Ajustar el modelo a los datos de entrenamiento
fit_ets_model = ets_model.fit()

# Realizar predicciones en los datos de prueba
y_pred_ets = fit_ets_model.predict(start=len(y_train), end=len(y_train) + len(y_test) - 1)

# Filtrar datos reales para los años 2011 a 2021
actual_y_2011_2021 = scaled_df.loc[(scaled_df.index >= 2011) & (scaled_df.index <= 2021), 'KEROSENE/JET FUEL/TS']

# Calcular el error cuadrático medio (MSE)
mse_ets = mean_squared_error(actual_y_2011_2021, y_pred_ets)

# Comparar valores predichos con valores reales
plt.figure(figsize=(10, 6))
plt.plot(actual_y_2011_2021.index, actual_y_2011_2021, label='Valor Real')
plt.plot(actual_y_2011_2021.index, y_pred_ets, label='Valor Predicho (ETS)')
plt.xlabel('Año')
plt.ylabel('KEROSENE/JET FUEL/TS')
plt.title('Comparación de Valores Predichos y Reales (ETS)')
plt.legend()
plt.ylim(0, 1)  # Establecer límites del eje y entre 0 y 1
plt.show()

print("Mean Squared Error (ETS):", mse_ets)
# Out:
# C:\Users\abomi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\abomi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Mean Squared Error (ETS): 4.90715954924888e-05

# %%
from sklearn.ensemble import RandomForestRegressor

# Crear un modelo de Regresión Aleatoria (Random Forest)
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# Ajustar el modelo a los datos de entrenamiento
rf_model.fit(X_train, y_train)

# Realizar predicciones en los datos de prueba
y_pred_rf = rf_model.predict(X_test)

# Calcular el error cuadrático medio (MSE)
mse_rf = mean_squared_error(y_test, y_pred_rf)

# Comparar valores predichos con valores reales
plt.figure(figsize=(10, 6))
plt.plot(actual_y_2011_2021.index, actual_y_2011_2021, label='Valor Real')
plt.plot(X_test.index, y_pred_rf, label='Valor Predicho (Random Forest)')
plt.xlabel('Año')
plt.ylabel('KEROSENE/JET FUEL/TS')
plt.title('Comparación de Valores Predichos y Reales (Random Forest)')
plt.legend()
plt.ylim(0, 1)  # Establecer límites del eje y entre 0 y 1
plt.show()

print("Mean Squared Error (Random Forest):", mse_rf)
# Out:
# Mean Squared Error (Random Forest): 0.00010694347138439984

# %%
from sklearn.ensemble import GradientBoostingRegressor

# Crear un modelo de Regresión por Gradiente (Gradient Boosting)
gb_model = GradientBoostingRegressor(n_estimators=100, random_state=42)

# Ajustar el modelo a los datos de entrenamiento
gb_model.fit(X_train, y_train)

# Realizar predicciones en los datos de prueba
y_pred_gb = gb_model.predict(X_test)

# Calcular el error cuadrático medio (MSE)
mse_gb = mean_squared_error(y_test, y_pred_gb)

# Comparar valores predichos con valores reales
plt.figure(figsize=(10, 6))
plt.plot(actual_y_2011_2021.index, actual_y_2011_2021, label='Valor Real')
plt.plot(X_test.index, y_pred_gb, label='Valor Predicho (Gradient Boosting)')
plt.xlabel('Año')
plt.ylabel('KEROSENE/JET FUEL/TS')
plt.title('Comparación de Valores Predichos y Reales (Gradient Boosting)')
plt.legend()
plt.ylim(0, 1)  # Establecer límites del eje y entre 0 y 1
plt.show()

print("Mean Squared Error (Gradient Boosting):", mse_gb)
# Out:
# Mean Squared Error (Gradient Boosting): 0.00013294049752415147

# %%
import xgboost as xgb

# Crear un modelo de Regresión Extrema de Gradiente (XGBoost)
xgb_model = xgb.XGBRegressor(n_estimators=100)

# Ajustar el modelo a los datos de entrenamiento
xgb_model.fit(X_train, y_train)

# Realizar predicciones en los datos de prueba
y_pred_xgb = xgb_model.predict(X_test)

# Calcular el error cuadrático medio (MSE)
mse_xgb = mean_squared_error(y_test, y_pred_xgb)

# Comparar valores predichos con valores reales
plt.figure(figsize=(10, 6))
plt.plot(actual_y_2011_2021.index, actual_y_2011_2021, label='Valor Real')
plt.plot(X_test.index, y_pred_xgb, label='Valor Predicho (XGBoost)')
plt.xlabel('Año')
plt.ylabel('KEROSENE/JET FUEL/TS')
plt.title('Comparación de Valores Predichos y Reales (XGBoost)')
plt.legend()
plt.ylim(0, 1)  # Establecer límites del eje y entre 0 y 1
plt.show()

print("Mean Squared Error (XGBoost):", mse_xgb)
# Out:
# Mean Squared Error (XGBoost): 0.00011202715397587043

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

# Cargar tus datos y dividirlos en conjuntos de entrenamiento y validación
# X y y representan tus características y etiquetas, respectivamente

# Preprocesar los datos
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_val, y_train, y_val = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Definir la arquitectura del modelo
model = Sequential()
model.add(Dense(128, activation='relu', input_dim=X_train.shape[1]))
model.add(Dropout(0.5))  # Agregar dropout para evitar overfitting
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='linear'))  # Capa de salida lineal para regresión

# Compilar el modelo con un optimizador personalizado
optimizer = Adam(learning_rate=0.001)
model.compile(loss='mean_squared_error', optimizer=optimizer)

# Entrenar el modelo
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_val, y_val), verbose=1)

# Realizar predicciones en los datos de prueba
y_pred = model.predict(X_val)

# Calcular el error cuadrático medio (MSE)
mse = mean_squared_error(y_val, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 2s 272ms/step - loss: 0.0433 - val_loss: 0.0035
# Epoch 2/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0447 - val_loss: 0.0021
# Epoch 3/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0481 - val_loss: 0.0026
# Epoch 4/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0540 - val_loss: 0.0036
# Epoch 5/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0246 - val_loss: 0.0070
# Epoch 6/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0219 - val_loss: 0.0131
# Epoch 7/100
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0364 - val_loss: 0.0120
# Epoch 8/100
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0176 - val_loss: 0.0082
# Epoch 9/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0189 - val_loss: 0.0042
# Epoch 10/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0122 - val_loss: 0.0045
# Epoch 11/100
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0197 - val_loss: 0.0051
# Epoch 12/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0115 - val_loss: 0.0032
# Epoch 13/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0187 - val_loss: 0.0024
# Epoch 14/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0085 - val_loss: 0.0033
# Epoch 15/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0109 - val_loss: 0.0043
# Epoch 16/100
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0114 - val_loss: 0.0043
# Epoch 17/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0157 - val_loss: 0.0039
# Epoch 18/100
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0129 - val_loss: 0.0032
# Epoch 19/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0108 - val_loss: 0.0023
# Epoch 20/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0087 - val_loss: 0.0015
# Epoch 21/100
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0085 - val_loss: 0.0011
# Epoch 22/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0092 - val_loss: 0.0019
# Epoch 23/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0062 - val_loss: 0.0034
# Epoch 24/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0094 - val_loss: 0.0060
# Epoch 25/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0043 - val_loss: 0.0070
# Epoch 26/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0100 - val_loss: 0.0053
# Epoch 27/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0049 - val_loss: 0.0032
# Epoch 28/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0065 - val_loss: 0.0023
# Epoch 29/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0117 - val_loss: 0.0023
# Epoch 30/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0049 - val_loss: 0.0028
# Epoch 31/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0076 - val_loss: 0.0029
# Epoch 32/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 33/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0069 - val_loss: 0.0027
# Epoch 34/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0028 - val_loss: 0.0020
# Epoch 35/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0059 - val_loss: 0.0016
# Epoch 36/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0059 - val_loss: 0.0013
# Epoch 37/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0034 - val_loss: 0.0011
# Epoch 38/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0044 - val_loss: 0.0014
# Epoch 39/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0092 - val_loss: 0.0017
# Epoch 40/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0041 - val_loss: 0.0024
# Epoch 41/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0049 - val_loss: 0.0026
# Epoch 42/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0052 - val_loss: 0.0023
# Epoch 43/100
# 3/3 [==============================] - 0s 109ms/step - loss: 0.0039 - val_loss: 0.0022
# Epoch 44/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0049 - val_loss: 0.0025
# Epoch 45/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0053 - val_loss: 0.0018
# Epoch 46/100
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0036 - val_loss: 0.0013
# Epoch 47/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0054 - val_loss: 0.0021
# Epoch 48/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0055 - val_loss: 0.0034
# Epoch 49/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0066 - val_loss: 0.0027
# Epoch 50/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0050 - val_loss: 0.0019
# Epoch 51/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0063 - val_loss: 0.0019
# Epoch 52/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0020 - val_loss: 0.0026
# Epoch 53/100
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0043 - val_loss: 0.0031
# Epoch 54/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 55/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0045 - val_loss: 0.0022
# Epoch 56/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0054 - val_loss: 0.0013
# Epoch 57/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0020 - val_loss: 7.9943e-04
# Epoch 58/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0048 - val_loss: 7.3111e-04
# Epoch 59/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0081 - val_loss: 7.5322e-04
# Epoch 60/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0044 - val_loss: 0.0012
# Epoch 61/100
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 62/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0049 - val_loss: 0.0024
# Epoch 63/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 64/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 65/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0032 - val_loss: 0.0015
# Epoch 66/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0021 - val_loss: 0.0010
# Epoch 67/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0047 - val_loss: 5.8548e-04
# Epoch 68/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0028 - val_loss: 4.2602e-04
# Epoch 69/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0069 - val_loss: 6.4627e-04
# Epoch 70/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0029 - val_loss: 0.0011
# Epoch 71/100
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 72/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 73/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0026 - val_loss: 0.0018
# Epoch 74/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0037 - val_loss: 0.0020
# Epoch 75/100
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0030 - val_loss: 0.0022
# Epoch 76/100
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0033 - val_loss: 0.0026
# Epoch 77/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 78/100
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 79/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0033 - val_loss: 0.0014
# Epoch 80/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0025 - val_loss: 0.0011
# Epoch 81/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0042 - val_loss: 9.8899e-04
# Epoch 82/100
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 83/100
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 84/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 85/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 86/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 87/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0034 - val_loss: 0.0015
# Epoch 88/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 89/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0043 - val_loss: 0.0015
# Epoch 90/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 91/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0034 - val_loss: 0.0025
# Epoch 92/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0031 - val_loss: 0.0022
# Epoch 93/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 94/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0027 - val_loss: 0.0021
# Epoch 95/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 96/100
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0027 - val_loss: 0.0010
# Epoch 97/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0027 - val_loss: 7.6774e-04
# Epoch 98/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0018 - val_loss: 9.3780e-04
# Epoch 99/100
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 100/100
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0015 - val_loss: 0.0012
# 1/1 [==============================] - 0s 250ms/step
# Mean Squared Error: 0.0011756697817654892

# %% [markdown]
# ## PREDICCIÓN LOS PRÓXIMOS 20 AÑOS

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# Suponiendo que tus datos estén en orden cronológico
X = np.arange(len(pivot_df)).reshape(-1, 1)
y = pivot_df['GASOLINE-ALCOHOL/TS'].values

model = LinearRegression()
model.fit(X, y)

# Prediciendo 20 puntos en el futuro
X_future = np.arange(len(pivot_df), len(pivot_df) + 20).reshape(-1, 1)
predictions = model.predict(X_future)

print("Predicciones para los próximos 20 años:", predictions)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Suponiendo que tus datos estén en orden cronológico
X = np.arange(len(pivot_df)).reshape(-1, 1)
y = pivot_df['GASOLINE-ALCOHOL/TS'].values

model = LinearRegression()
model.fit(X, y)

# Prediciendo 20 puntos en el futuro
X_future = np.arange(len(pivot_df), len(pivot_df) + 20).reshape(-1, 1)
predictions = model.predict(X_future)

# Gráfico de los datos actuales
plt.plot(X, y, label="Datos Actuales")

# Gráfico de las predicciones
plt.plot(X_future, predictions, label="Predicciones a 20 años", linestyle='dashed')

plt.xlabel("Tiempo")
plt.ylabel("GASOLINE-ALCOHOL/TS")
plt.legend()
plt.title("Predicción a 20 años de GASOLINE-ALCOHOL/TS")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# Asumiendo que tus datos están en orden cronológico y son estacionarios
y_scaled = pivot_df['TRANSPORT/FC'].values
y = y_scaled * 10

# Ajustando el modelo ARIMA
# Puedes ajustar los parámetros p, d, q según tu serie temporal
model = ARIMA(y, order=(5,1,0))
fit_model = model.fit()

# Haciendo una predicción para los próximos 20 puntos
forecast = fit_model.forecast(steps=20)

# Gráfico de los datos actuales
plt.plot(y, label="Datos Actuales")

# Gráfico de las predicciones
plt.plot(range(len(y), len(y) + 20), forecast, label="Predicciones a 20 años", linestyle='dashed')

plt.xlabel("Tiempo")
plt.ylabel("TRANSPORT/FC")
plt.legend()
plt.title("Predicción a 20 años de TRANSPORT/FC con ARIMA")
plt.show()

# %% [markdown]
# 1. Modelo de Suavizado Exponencial (Exponential Smoothing)

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

model = ExponentialSmoothing(y, trend='add')
fit_model = model.fit()

forecast = fit_model.forecast(steps=20)

plt.plot(y, label="Datos Actuales")
plt.plot(range(len(y), len(y) + 20), forecast, label="Predicciones a 20 años", linestyle='dashed')
plt.legend()
plt.show()

# %% [markdown]
# 3. Modelo de Regresión Polinomial

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

poly = PolynomialFeatures(degree=3)
X_poly = poly.fit_transform(X)

model = LinearRegression()
model.fit(X_poly, y)

X_future_poly = poly.transform(X_future)
predictions = model.predict(X_future_poly)

plt.plot(X, y, label="Datos Actuales")
plt.plot(X_future, predictions, label="Predicciones a 20 años", linestyle='dashed')
plt.legend()
plt.show()

# %%
from sklearn.linear_model import Lasso

lasso_model = Lasso(alpha=0.1)
lasso_model.fit(X, y)
predictions = lasso_model.predict(X_future)

plt.plot(y, label="Datos Actuales")
plt.plot(range(len(y), len(y) + 20), predictions, label="Predicciones a 20 años", linestyle='dashed')
plt.legend()
plt.show()

# %%
from sklearn.linear_model import Ridge

ridge_model = Ridge(alpha=0.1)
ridge_model.fit(X, y)
predictions = ridge_model.predict(X_future)

plt.plot(y, label="Datos Actuales")
plt.plot(range(len(y), len(y) + 20), predictions, label="Predicciones a 20 años", linestyle='dashed')
plt.legend()
plt.show()

# %%
from sklearn.linear_model import ElasticNet

elastic_model = ElasticNet(alpha=0.1, l1_ratio=0.5)
elastic_model.fit(X, y)
predictions = elastic_model.predict(X_future)

plt.plot(y, label="Datos Actuales")
plt.plot(range(len(y), len(y) + 20), predictions, label="Predicciones a 20 años", linestyle='dashed')
plt.legend()
plt.show()

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Puedes ajustar los parámetros de estacionalidad según tus datos
model = SARIMAX(y, order=(5, 1, 0), seasonal_order=(0, 1, 1, 12))
fit_model = model.fit()

forecast = fit_model.get_forecast(steps=20)

plt.plot(y, label="Datos Actuales")
plt.plot(range(len(y), len(y) + 20), forecast.predicted_mean, label="Predicciones a 20 años", linestyle='dashed')
plt.legend()
plt.show()

# %% [markdown]
# **Suavizado Exponencial Estado-Espacio (ETS)**

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# Ajusta el modelo ETS
ets_model = ExponentialSmoothing(y, trend='add', seasonal='add', seasonal_periods=12)
fit_model = ets_model.fit()

# Predicción a 20 años
forecast = fit_model.forecast(steps=20)

plt.plot(y, label="Datos Actuales")
plt.plot(range(len(y), len(y) + 20), forecast, label="Predicciones a 20 años", linestyle='dashed')
plt.legend()
plt.show()

# %%
pip install arch

# %% [markdown]
# Modelos GARCH

# %%
from arch import arch_model

# Ajusta el modelo GARCH(1, 1)
garch_model = arch_model(y, vol='Garch', p=1, q=1)
fit_model = garch_model.fit()

# Predicción de la varianza (volatilidad) a 20 años
forecasts = fit_model.forecast(start=0, horizon=20)
future_volatility = forecasts.variance.dropna().iloc[-1]

plt.plot(y, label="Datos Actuales")
plt.plot(range(len(y), len(y) + 20), future_volatility, label="Predicciones de Volatilidad a 20 años", linestyle='dashed')
plt.legend()
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt

# Crear y entrenar el modelo
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X, y)

# Hacer predicciones a 20 años
predictions = rf_model.predict(X_future)

plt.plot(y, label="Datos Actuales")
plt.plot(range(len(y), len(y) + 20), predictions, label="Predicciones a 20 años", linestyle='dashed')
plt.legend()
plt.show()

# %%
from sklearn.ensemble import GradientBoostingRegressor

# Crear y entrenar el modelo
gb_model = GradientBoostingRegressor(n_estimators=100, random_state=42)
gb_model.fit(X, y)

# Hacer predicciones a 20 años
predictions = gb_model.predict(X_future)

plt.plot(y, label="Datos Actuales")
plt.plot(range(len(y), len(y) + 20), predictions, label="Predicciones a 20 años", linestyle='dashed')
plt.legend()
plt.show()

# %%
import xgboost as xgb

# Crear y entrenar el modelo
xgb_model = xgb.XGBRegressor(n_estimators=100)
xgb_model.fit(X, y)

# Hacer predicciones a 20 años
predictions = xgb_model.predict(X_future)

plt.plot(y, label="Datos Actuales")
plt.plot(range(len(y), len(y) + 20), predictions, label="Predicciones a 20 años", linestyle='dashed')
plt.legend()
plt.show()
